# %% [markdown]
# Question 9 -
#
# Write a program to read the data from the following link, perform data analysis and answer the following
# questions
#
# Note -
# 1.Write code comments wherever required for code understanding
#
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
#
# Insights to be drawn -
# ● Get all the cars and their types that do not qualify for clean alternative fuel vehicle
# ● Get all TESLA cars with the model year, and model type made in Bothell City.
# ● Get all the cars that have an electric range of more than 100, and were made after
# 2015
# ● Draw plots to show the distribution between city and electric vehicle type

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the CSV data from the link
url = "https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(url)

# %%
df.head(50)
# Out:
#     VIN (1-10)     County               City State  Postal Code  Model Year  \
# 0   5YJXCAE26J     Yakima             Yakima    WA      98908.0        2018
# 1   JHMZC5F37M     Kitsap            Poulsbo    WA      98370.0        2021
# 2   5YJ3E1EB0K       King            Seattle    WA      98199.0        2019
# 3   1N4AZ0CP5D       King            Seattle    WA      98119.0        2013
# 4   5YJSA1E21H   Thurston              Lacey    WA      98516.0        2017
# 5   JHMZC5F1XJ   Thurston            Olympia    WA      98506.0        2018
# 6   3FA6P0PU1G   Thurston           Tumwater    WA      98501.0        2016
# 7   WA1F2AFY8P   Thurston              Lacey    WA      98516.0        2023
# 8   1FADP5CU0E   Thurston          Rochester    WA      98579.0        2014
# 9   5YJSA1CP1D     Kitsap          Bremerton    WA      98312.0        2013
# 10  1N4AZ0CP3F   Thurston              Lacey    WA      98503.0        2015
# 11  7SAYGDEF4N     Yakima             Yakima    WA      98908.0        2022
# 12  5YJ3E1EC7L   Thurston              Lacey    WA      98503.0        2020
# 13  5YJ3E1EB2L   Thurston            Olympia    WA      98516.0        2020
# 14  1FADP5FU4H   Thurston              Lacey    WA      98513.0        2017
# 15  KNDCM3LD8L     Kitsap  Bainbridge Island    WA      98110.0        2020
# 16  1N4AZ0CP0F     Yakima             Yakima    WA      98902.0        2015
# 17  5YJSA1S18E   Thurston            Olympia    WA      98502.0        2014
# 18  1G1RC6E46F  Snohomish            Everett    WA      98204.0        2015
# 19  1G1FX6S0XH     Chelan        Leavenworth    WA      98826.0        2017
# 20  5YJ3E1EA9L   Thurston              Lacey    WA      98516.0        2020
# 21  5YJSA1DN0D  Snohomish         Mill Creek    WA      98012.0        2013
# 22  1G1RA6E47C  Snohomish          Snohomish    WA      98290.0        2012
# 23  1N4BZ0CP1H   Thurston            Olympia    WA      98506.0        2017
# 24  5YJSA1DP5D     Skagit       Mount Vernon    WA      98273.0        2013
# 25  WMEFJ9BA6H  Snohomish          Arlington    WA      98223.0        2017
# 26  JN1AZ0CP4C       King            Seattle    WA      98103.0        2012
# 27  1N4AZ1CP9J   Thurston            Olympia    WA      98502.0        2018
# 28  5YJ3E1EB4K     Yakima             Yakima    WA      98902.0        2019
# 29  5UXKT0C33H  Snohomish       Lake Stevens    WA      98258.0        2017
# 30  5YJYGDEEXL  Snohomish          Snohomish    WA      98296.0        2020
# 31  5YJ3E1EB8K     Skagit         Burlington    WA      98233.0        2019
# 32  5YJ3E1EA0J     Skagit          Anacortes    WA      98221.0        2018
# 33  1N4AZ0CP7D     Skagit          Anacortes    WA      98221.0        2013
# 34  1N4AZ1CP7J  Snohomish            Edmonds    WA      98020.0        2018
# 35  5YJ3E1EB6L  Snohomish            Everett    WA      98201.0        2020
# 36  KNDRJDLH1N  Snohomish            Bothell    WA      98021.0        2022
# 37  1G1FZ6S08L  Snohomish             Sultan    WA      98294.0        2020
# 38  5YJ3E1EB9J    Spokane            Spokane    WA      99207.0        2018
# 39  5YJ3E1EA6L  Snohomish            Bothell    WA      98012.0        2020
# 40  JTDKARFP5L  Snohomish       Lake Stevens    WA      98258.0        2020
# 41  WBY1Z4C57F    Whitman            Pullman    WA      99163.0        2015
# 42  1N4AZ1CP0L  Snohomish          Snohomish    WA      98296.0        2020
# 43  5YJSA1E15H   Thurston               Yelm    WA      98597.0        2017
# 44  1N4AZ0CPXD  Snohomish       Lake Stevens    WA      98258.0        2013
# 45  5YJXCDE27H     Yakima             Yakima    WA      98901.0        2017
# 46  1N4AZ0CP8D     Kitsap       Port Orchard    WA      98366.0        2013
# 47  1G1FX6S00H  Snohomish          Arlington    WA      98223.0        2017
# 48  5YJ3E1EB0K     Kitsap  Bainbridge Island    WA      98110.0        2019
# 49  5YJ3E1EB8L  Snohomish            Edmonds    WA      98020.0        2020
#
#          Make        Model                   Electric Vehicle Type  \
# 0       TESLA      MODEL X          Battery Electric Vehicle (BEV)
# 1       HONDA      CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2       TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 3      NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 4       TESLA      MODEL S          Battery Electric Vehicle (BEV)
# 5       HONDA      CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 6        FORD       FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 7        AUDI         Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 8        FORD        C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# 9       TESLA      MODEL S          Battery Electric Vehicle (BEV)
# 10     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 11      TESLA      MODEL Y          Battery Electric Vehicle (BEV)
# 12      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 13      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 14       FORD        C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# 15        KIA         NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 16     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 17      TESLA      MODEL S          Battery Electric Vehicle (BEV)
# 18  CHEVROLET         VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 19  CHEVROLET      BOLT EV          Battery Electric Vehicle (BEV)
# 20      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 21      TESLA      MODEL S          Battery Electric Vehicle (BEV)
# 22  CHEVROLET         VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 23     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 24      TESLA      MODEL S          Battery Electric Vehicle (BEV)
# 25      SMART       FORTWO          Battery Electric Vehicle (BEV)
# 26     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 27     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 28      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 29        BMW           X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 30      TESLA      MODEL Y          Battery Electric Vehicle (BEV)
# 31      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 32      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 33     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 34     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 35      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 36        KIA      SORENTO  Plug-in Hybrid Electric Vehicle (PHEV)
# 37  CHEVROLET      BOLT EV          Battery Electric Vehicle (BEV)
# 38      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 39      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 40     TOYOTA  PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 41        BMW           I3  Plug-in Hybrid Electric Vehicle (PHEV)
# 42     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 43      TESLA      MODEL S          Battery Electric Vehicle (BEV)
# 44     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 45      TESLA      MODEL X          Battery Electric Vehicle (BEV)
# 46     NISSAN         LEAF          Battery Electric Vehicle (BEV)
# 47  CHEVROLET      BOLT EV          Battery Electric Vehicle (BEV)
# 48      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
# 49      TESLA      MODEL 3          Battery Electric Vehicle (BEV)
#
#     Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0             Clean Alternative Fuel Vehicle Eligible             238
# 1             Clean Alternative Fuel Vehicle Eligible              47
# 2             Clean Alternative Fuel Vehicle Eligible             220
# 3             Clean Alternative Fuel Vehicle Eligible              75
# 4             Clean Alternative Fuel Vehicle Eligible             210
# 5             Clean Alternative Fuel Vehicle Eligible              47
# 6               Not eligible due to low battery range              19
# 7               Not eligible due to low battery range              23
# 8               Not eligible due to low battery range              19
# 9             Clean Alternative Fuel Vehicle Eligible             208
# 10            Clean Alternative Fuel Vehicle Eligible              84
# 11  Eligibility unknown as battery range has not b...               0
# 12            Clean Alternative Fuel Vehicle Eligible             308
# 13            Clean Alternative Fuel Vehicle Eligible             322
# 14              Not eligible due to low battery range              20
# 15              Not eligible due to low battery range              26
# 16            Clean Alternative Fuel Vehicle Eligible              84
# 17            Clean Alternative Fuel Vehicle Eligible             208
# 18            Clean Alternative Fuel Vehicle Eligible              38
# 19            Clean Alternative Fuel Vehicle Eligible             238
# 20            Clean Alternative Fuel Vehicle Eligible             266
# 21            Clean Alternative Fuel Vehicle Eligible             208
# 22            Clean Alternative Fuel Vehicle Eligible              35
# 23            Clean Alternative Fuel Vehicle Eligible             107
# 24            Clean Alternative Fuel Vehicle Eligible             208
# 25            Clean Alternative Fuel Vehicle Eligible              58
# 26            Clean Alternative Fuel Vehicle Eligible              73
# 27            Clean Alternative Fuel Vehicle Eligible             151
# 28            Clean Alternative Fuel Vehicle Eligible             220
# 29              Not eligible due to low battery range              14
# 30            Clean Alternative Fuel Vehicle Eligible             291
# 31            Clean Alternative Fuel Vehicle Eligible             220
# 32            Clean Alternative Fuel Vehicle Eligible             215
# 33            Clean Alternative Fuel Vehicle Eligible              75
# 34            Clean Alternative Fuel Vehicle Eligible             151
# 35            Clean Alternative Fuel Vehicle Eligible             322
# 36            Clean Alternative Fuel Vehicle Eligible              32
# 37            Clean Alternative Fuel Vehicle Eligible             259
# 38            Clean Alternative Fuel Vehicle Eligible             215
# 39            Clean Alternative Fuel Vehicle Eligible             266
# 40              Not eligible due to low battery range              25
# 41            Clean Alternative Fuel Vehicle Eligible              72
# 42            Clean Alternative Fuel Vehicle Eligible             149
# 43            Clean Alternative Fuel Vehicle Eligible             210
# 44            Clean Alternative Fuel Vehicle Eligible              75
# 45            Clean Alternative Fuel Vehicle Eligible             200
# 46            Clean Alternative Fuel Vehicle Eligible              75
# 47            Clean Alternative Fuel Vehicle Eligible             238
# 48            Clean Alternative Fuel Vehicle Eligible             220
# 49            Clean Alternative Fuel Vehicle Eligible             322
#
#     Base MSRP  Legislative District  DOL Vehicle ID  \
# 0           0                  14.0       141151601
# 1           0                  23.0       171566447
# 2           0                  36.0         9426525
# 3           0                  36.0       211807760
# 4           0                  22.0       185810306
# 5           0                  22.0       153785726
# 6           0                  22.0       347508836
# 7           0                  22.0       227213871
# 8           0                  20.0       229811151
# 9       69900                  26.0       164768075
# 10          0                  22.0       193420811
# 11          0                  14.0       187486883
# 12          0                  22.0         2135486
# 13          0                  22.0       124645363
# 14          0                  22.0       139887513
# 15          0                  23.0       157737730
# 16          0                  14.0       124092398
# 17      69900                  22.0       235148434
# 18          0                  21.0       224494658
# 19          0                  12.0       133848662
# 20          0                  22.0       103034676
# 21      69900                  44.0       130615607
# 22          0                  44.0       207801492
# 23          0                  22.0       258019618
# 24      69900                  40.0       228899387
# 25          0                  38.0       153988418
# 26          0                  36.0       181732477
# 27          0                  35.0       111803415
# 28          0                  14.0       270673084
# 29          0                  44.0       146525333
# 30          0                   1.0       107819932
# 31          0                  10.0       324917085
# 32          0                  40.0       333177358
# 33          0                  40.0       247282486
# 34          0                  21.0       235442777
# 35          0                  38.0       101991081
# 36          0                   1.0       190573260
# 37          0                  39.0       166824304
# 38          0                   3.0       286454864
# 39          0                  21.0       127506886
# 40          0                  44.0       177542704
# 41          0                   9.0       218329275
# 42          0                   1.0       132843623
# 43          0                   2.0       477498283
# 44          0                  44.0       243742670
# 45          0                  15.0       193775536
# 46          0                  26.0       163198437
# 47          0                  39.0       260006043
# 48          0                  23.0       478792107
# 49          0                  21.0       102950508
#
#                                  Vehicle Location  \
# 0                     POINT (-120.56916 46.58514)
# 1                     POINT (-122.64681 47.73689)
# 2                     POINT (-122.40092 47.65908)
# 3                      POINT (-122.3684 47.64586)
# 4                     POINT (-122.75379 47.06316)
# 5                     POINT (-122.87741 47.05997)
# 6                     POINT (-122.89166 47.03956)
# 7                     POINT (-122.75379 47.06316)
# 8                     POINT (-123.08743 46.82175)
# 9                     POINT (-122.66122 47.56573)
# 10                    POINT (-122.82324 47.04437)
# 11                    POINT (-120.56916 46.58514)
# 12                    POINT (-122.82324 47.04437)
# 13                    POINT (-122.75379 47.06316)
# 14  POINT (-122.81754499999994 46.98876000000007)
# 15                      POINT (-122.521 47.62728)
# 16                    POINT (-120.52301 46.60138)
# 17                    POINT (-122.92333 47.03779)
# 18                    POINT (-122.25527 47.90456)
# 19                     POINT (-120.65754 47.5982)
# 20                    POINT (-122.75379 47.06316)
# 21                    POINT (-122.21061 47.83448)
# 22                    POINT (-122.09305 47.91265)
# 23                    POINT (-122.87741 47.05997)
# 24  POINT (-122.33897499999995 48.41333000000003)
# 25                     POINT (-122.1264 48.19471)
# 26                    POINT (-122.35436 47.67596)
# 27                    POINT (-122.92333 47.03779)
# 28                    POINT (-120.52301 46.60138)
# 29                    POINT (-122.06402 48.01497)
# 30                     POINT (-122.1389 47.87115)
# 31                    POINT (-122.33029 48.46846)
# 32                    POINT (-122.61214 48.51748)
# 33                    POINT (-122.61214 48.51748)
# 34                    POINT (-122.37689 47.81116)
# 35                    POINT (-122.20596 47.97659)
# 36                     POINT (-122.18384 47.8031)
# 37                     POINT (-121.81688 47.8623)
# 38                     POINT (-117.3973 47.67573)
# 39                    POINT (-122.21061 47.83448)
# 40                    POINT (-122.06402 48.01497)
# 41                    POINT (-117.18147 46.73015)
# 42                     POINT (-122.1389 47.87115)
# 43                    POINT (-122.60735 46.94239)
# 44                    POINT (-122.06402 48.01497)
# 45                    POINT (-120.50721 46.60448)
# 46                    POINT (-122.63847 47.54103)
# 47                     POINT (-122.1264 48.19471)
# 48                      POINT (-122.521 47.62728)
# 49                    POINT (-122.37689 47.81116)
#
#                                 Electric Utility  2020 Census Tract
# 0                                     PACIFICORP       5.307700e+10
# 1                         PUGET SOUND ENERGY INC       5.303509e+10
# 2   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 3   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                         PUGET SOUND ENERGY INC       5.306701e+10
# 5                         PUGET SOUND ENERGY INC       5.306701e+10
# 6                         PUGET SOUND ENERGY INC       5.306701e+10
# 7                         PUGET SOUND ENERGY INC       5.306701e+10
# 8                         PUGET SOUND ENERGY INC       5.306701e+10
# 9                         PUGET SOUND ENERGY INC       5.303508e+10
# 10                        PUGET SOUND ENERGY INC       5.306701e+10
# 11                                    PACIFICORP       5.307700e+10
# 12                        PUGET SOUND ENERGY INC       5.306701e+10
# 13                        PUGET SOUND ENERGY INC       5.306701e+10
# 14                        PUGET SOUND ENERGY INC       5.306701e+10
# 15                        PUGET SOUND ENERGY INC       5.303509e+10
# 16                                    PACIFICORP       5.307700e+10
# 17                        PUGET SOUND ENERGY INC       5.306701e+10
# 18                        PUGET SOUND ENERGY INC       5.306104e+10
# 19                     PUD NO 1 OF CHELAN COUNTY       5.300796e+10
# 20                        PUGET SOUND ENERGY INC       5.306701e+10
# 21                        PUGET SOUND ENERGY INC       5.306104e+10
# 22                        PUGET SOUND ENERGY INC       5.306105e+10
# 23                        PUGET SOUND ENERGY INC       5.306701e+10
# 24                        PUGET SOUND ENERGY INC       5.305795e+10
# 25                        PUGET SOUND ENERGY INC       5.306105e+10
# 26  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 27                        PUGET SOUND ENERGY INC       5.306701e+10
# 28                                    PACIFICORP       5.307700e+10
# 29                        PUGET SOUND ENERGY INC       5.306105e+10
# 30                        PUGET SOUND ENERGY INC       5.306105e+10
# 31                        PUGET SOUND ENERGY INC       5.305795e+10
# 32                        PUGET SOUND ENERGY INC       5.305794e+10
# 33                        PUGET SOUND ENERGY INC       5.305794e+10
# 34                        PUGET SOUND ENERGY INC       5.306105e+10
# 35                        PUGET SOUND ENERGY INC       5.306104e+10
# 36                        PUGET SOUND ENERGY INC       5.306105e+10
# 37                        PUGET SOUND ENERGY INC       5.306105e+10
# 38                 MODERN ELECTRIC WATER COMPANY       5.306300e+10
# 39                        PUGET SOUND ENERGY INC       5.306105e+10
# 40                        PUGET SOUND ENERGY INC       5.306105e+10
# 41                                   AVISTA CORP       5.307500e+10
# 42                        PUGET SOUND ENERGY INC       5.306105e+10
# 43                        PUGET SOUND ENERGY INC       5.306701e+10
# 44                        PUGET SOUND ENERGY INC       5.306105e+10
# 45                                    PACIFICORP       5.307700e+10
# 46                        PUGET SOUND ENERGY INC       5.303509e+10
# 47                        PUGET SOUND ENERGY INC       5.306105e+10
# 48                        PUGET SOUND ENERGY INC       5.303509e+10
# 49                        PUGET SOUND ENERGY INC       5.306105e+10

# %%
print("Column names:")
print(df.columns)
# Out:
# Column names:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
# Get all cars and their types that do not qualify for clean alternative fuel vehicle
non_clean_fuel_cars = df.loc[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] != 'Clean Alternative Fuel Vehicle Eligible', ['Make', 'Model']]
print("Cars and their types that do not qualify for clean alternative fuel vehicle:")
print(non_clean_fuel_cars)
# Out:
# Cars and their types that do not qualify for clean alternative fuel vehicle:
#           Make    Model
# 6         FORD   FUSION
# 7         AUDI     Q5 E
# 8         FORD    C-MAX
# 11       TESLA  MODEL Y
# 14        FORD    C-MAX
# ...        ...      ...
# 130437     BMW     530E
# 130438   TESLA  MODEL Y
# 130439  NISSAN     LEAF
# 130440   TESLA  MODEL Y
# 130442   TESLA  MODEL 3
#
# [69892 rows x 2 columns]

# %%
# Get all TESLA cars with the model year, and model type made in Bothell City
tesla_cars_bothell = df.loc[(df['Make'] == 'TESLA') & (df['City'] == 'BOTHELL'), ['Model Year', 'Model']]
print("TESLA cars with the model year and model type made in Bothell City:")
print(tesla_cars_bothell)
# Out:
# TESLA cars with the model year and model type made in Bothell City:
# Empty DataFrame
# Columns: [Model Year, Model]
# Index: []

# %%
# Get all cars with an electric range of more than 100 and made after 2015
electric_cars_gt_100_range = df.loc[(df['Electric Range'] > 100) & (df['Model Year'] > 2015)]
print("Cars with an electric range of more than 100 and made after 2015:")
print(electric_cars_gt_100_range)
# Out:
# Cars with an electric range of more than 100 and made after 2015:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# 0        TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 2        TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 4        TESLA  MODEL S  Battery Electric Vehicle (BEV)
# 12       TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 13       TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# ...        ...      ...                             ...
# 130417   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 130428  NISSAN     LEAF  Battery Electric Vehicle (BEV)
# 130432   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 130436   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 130441   TESLA  MODEL X  Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                Clean Alternative Fuel Vehicle Eligible             238
# 2                Clean Alternative Fuel Vehicle Eligible             220
# 4                Clean Alternative Fuel Vehicle Eligible             210
# 12               Clean Alternative Fuel Vehicle Eligible             308
# 13               Clean Alternative Fuel Vehicle Eligible             322
# ...                                                  ...             ...
# 130417           Clean Alternative Fuel Vehicle Eligible             291
# 130428           Clean Alternative Fuel Vehicle Eligible             151
# 130432           Clean Alternative Fuel Vehicle Eligible             291
# 130436           Clean Alternative Fuel Vehicle Eligible             215
# 130441           Clean Alternative Fuel Vehicle Eligible             293
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0               0                  14.0       141151601
# 2               0                  36.0         9426525
# 4               0                  22.0       185810306
# 12              0                  22.0         2135486
# 13              0                  22.0       124645363
# ...           ...                   ...             ...
# 130417          0                  29.0       112591538
# 130428          0                  24.0       290405174
# 130432          0                  34.0       112734723
# 130436          0                  42.0       103521302
# 130441          0                  10.0       102834938
#
#                                      Vehicle Location  \
# 0                         POINT (-120.56916 46.58514)
# 2                         POINT (-122.40092 47.65908)
# 4                         POINT (-122.75379 47.06316)
# 12                        POINT (-122.82324 47.04437)
# 13                        POINT (-122.75379 47.06316)
# ...                                               ...
# 130417                    POINT (-122.46495 47.16778)
# 130428  POINT (-123.09968999999995 48.08137000000005)
# 130432                     POINT (-122.4573 47.44929)
# 130436                    POINT (-122.74888 48.99404)
# 130441                    POINT (-122.40049 48.23986)
#
#                                          Electric Utility  2020 Census Tract
# 0                                              PACIFICORP       5.307700e+10
# 2            CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 4                                  PUGET SOUND ENERGY INC       5.306701e+10
# 12                                 PUGET SOUND ENERGY INC       5.306701e+10
# 13                                 PUGET SOUND ENERGY INC       5.306701e+10
# ...                                                   ...                ...
# 130417  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305306e+10
# 130428  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.300900e+10
# 130432      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 130436  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...       5.307301e+10
# 130441  BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOH...       5.302997e+10
#
# [34066 rows x 17 columns]

# %%
# Draw plots to show the distribution between city and electric vehicle type
plt.figure(figsize=(12, 6))
df['City'].value_counts().plot(kind='line', color='skyblue')
plt.xlabel('City')
plt.ylabel('Count')
plt.title('Distribution of Electric Vehicle Types by City')
plt.show()
